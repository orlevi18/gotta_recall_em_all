# %% [markdown]
# # High accuracy recall

# %%
import pandas as pd
import re
import random
import math

FILES_ROOT_PATH = '~/OneDrive - eBay Inc/High accuracy recall/'
MIN_WORD_COUNT = 5
USE_PHRASES = False
MIN_SIMILARITY_FOR_SYNONYMS = 0.7

# %% [markdown]
# ## Synonyms
# Could be used later on, not really used now

# %%
#pd_all_synonyms = pd.read_csv('~/OneDrive - eBay Inc/experiments/synonyms_from_searchpaths_split_keywords.csv')
pd_all_synonyms = pd.read_csv(FILES_ROOT_PATH + '/synonyms_english.csv')
#pd_all_synonyms = pd.read_csv('~/OneDrive - eBay Inc/experiments/casint 3005 Synonyms/synonyms_odw_checked.csv')
#pd_all_synonyms = pd.read_csv('~/OneDrive - eBay Inc/experiments/synonyms_twh/synonyms_ga_levenstein_nongrouped.csv')

#output_path = '~/OneDrive - eBay Inc/experiments/synonyms_twh/synonyms_ga_levenstein_grouped.csv'
output_path = FILES_ROOT_PATH + '/synonyms_english_90pct.csv'

MIN_SIMILARITY = 0.9
# ((pd_all_synonyms.loc[(pd_all_synonyms['CANDIDATE_STATUS']=='APPROVED')])
# .to_csv('~/OneDrive - eBay Inc/experiments/casint 3005 Synonyms/synonym_export_cleaned.csv'
#         , encoding='UTF8'))

# %%
pd_all_synonyms = pd_all_synonyms.loc[(pd_all_synonyms['CANDIDATE_STATUS']=='APPROVED')]
pd_all_synonyms = pd_all_synonyms.loc[(pd_all_synonyms['searches']>=10)]
pd_all_synonyms = pd_all_synonyms.loc[pd_all_synonyms['prev_keyword'].apply(lambda x: re.match('.*[0-9][a-z]?$', x) is None)]
pd_all_synonyms['keyword'] = pd_all_synonyms['prev_keyword']
pd_all_synonyms.head(5)
# Out:
#   CANDIDATE_STATUS prev_keyword    synonyms  searches  \
# 1         APPROVED          sec     sel slc        33
# 2         APPROVED         nail      nailer       228
# 3         APPROVED   mororcycle  motorcycle        33
# 4         APPROVED      cortina      corona        56
# 6         APPROVED          tun         tub        77
#
#                                       similarities     keyword
# 1  {sel=0.980449022031111, slc=0.9894410287758298}         sec
# 2                      {nailer=0.9501043566039408}        nail
# 3                  {motorcycle=0.9818345560015685}  mororcycle
# 4                      {corona=0.9851060539554997}     cortina
# 6                          {tub=0.813100311719324}         tun

# %%
pd.set_option('display.max_colwidth', -1)
pd_all_synonyms.loc[pd_all_synonyms.keyword=='ebike'].similarities
# Out:
# 12622    {bikes=0.8487290907659067, e-bike=0.9849325735139168, bike=0.9105030980084756}
# Name: similarities, dtype: object

# %%
import json
from json import JSONDecodeError

def extract_from_json(similarities, min_similarity):
    cleaned = similarities.replace('"', '_').replace('\\', '_')
    cleaned = re.sub(r'=([^0-9])', r'-\1', cleaned) 
    similarities = re.sub(r'([{]|, )([^=]*)=([0-9])', r'\1"\2":\3', cleaned) 
    try:
        d_synonyms = json.loads(similarities)
    except JSONDecodeError as e:
        print(cleaned, similarities)
        raise e
    return [key for key in d_synonyms if d_synonyms[key]>= min_similarity and re.match('.*[0-9][a-z]?$', key) is None]

extract_from_json(pd_all_synonyms.iloc[0]['similarities'], MIN_SIMILARITY)
# Out:
# ['sel', 'slc']

# %%
pd_all_synonyms['filtered_synonyms'] = pd_all_synonyms['similarities'].apply(lambda x: extract_from_json(x, MIN_SIMILARITY))

# %%
pd_all_synonyms.loc[(pd_all_synonyms['prev_keyword']=='iphonex')]
# Out:
#      CANDIDATE_STATUS prev_keyword synonyms  searches  \
# 3171  APPROVED         iphonex      iphone   69
#
#                      similarities  keyword filtered_synonyms
# 3171  {iphone=0.9979961841033886}  iphonex  [iphone]

# %%
def collapse_synonyms(pd_all_synonyms, word_column='keyword', synonyms_column='filtered_synonyms'):
    word_to_cluster = {}
    cluster_to_synonyms = {}
    for i,row in pd_all_synonyms.iterrows():
        found_cluster = None
        word = row[word_column] # keyword
        #synonyms = row.synonyms.split(' ')
        synonyms = row[synonyms_column] # .filtered_synonyms
        #if 'fietsendrag' in row.keyword:
        #print(word, synonyms)
        if isinstance(synonyms,str):
            synonyms = [synonyms]
        
        for synonym in synonyms:
            found_cluster = word_to_cluster.get(synonym)
            if found_cluster:
                break
        if not found_cluster:
            found_cluster = word_to_cluster.get(word)

        if not found_cluster:
            # Totally new
            word_to_cluster.update({synonym:word for synonym in synonyms})
            word_to_cluster.update({word:word})
            cluster_to_synonyms.update({word:set([word] + synonyms)})
        else:
            # Existing cluster
            # print('Merging', word, found_cluster)
            word_to_cluster.update({synonym:found_cluster for synonym in synonyms})
            word_to_cluster.update({word:found_cluster})
            cluster_to_synonyms.update({found_cluster:set([word] + synonyms 
                                                 + list(cluster_to_synonyms[found_cluster]))})
    return word_to_cluster, cluster_to_synonyms

word_to_cluster, cluster_to_synonyms = collapse_synonyms(pd_all_synonyms)
pd_collapsed = pd.DataFrame([(word, list(cluster_to_synonyms[word])) for word in cluster_to_synonyms.keys()]
                           , columns=['keyword', 'synonyms'])

# %%
import csv
pd_collapsed['flat_synonyms'] = pd_collapsed.apply(lambda r: ','.join(r.synonyms),axis=1)
pd_collapsed.to_csv(output_path
                    , index_label=False
                    , index=False
                    , header=False
                    , quoting = csv.QUOTE_NONE
                    , sep='|'
                    , quotechar="",  escapechar="\\"
                    , columns=['flat_synonyms']
                    , encoding='UTF8')

# %% [markdown]
# ## NLTK
# Only using stopwords for now :)

# %%
# First, you're going to need to import wordnet: 
import nltk
from nltk.corpus import wordnet
nltk.download('punkt')
nltk.download('alpino')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cpieterse\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package alpino to
# [nltk_data]     C:\Users\cpieterse\AppData\Roaming\nltk_data...
# [nltk_data]   Package alpino is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\cpieterse\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\cpieterse\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\cpieterse\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %% [markdown]
# ## Actual work
# ### Start reading the data

# %%
# Define input data
from gensim.utils import simple_preprocess
X, y = [], []
documents = pd.read_csv(FILES_ROOT_PATH + 'documents.tsv', sep='\t')
#with open(FILES_ROOT_PATH + 'documents.tsv', "r") as infile:
#    for line in infile:
#        doc_id,price,title,category_breadcrumb,itemid_image_url = line.split("\t")
#        label = '0'
#        X.append(simple_preprocess(title, deacc=True))
#        y.append(label)
#X, y = np.array(X), np.array(y)
# Out:
# C:\Users\cpieterse\AppData\Local\Continuum\anaconda3\lib\site-packages\smart_open\ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')
# C:\Users\cpieterse\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# Additional processing

# %%
from nltk.tokenize import TweetTokenizer, RegexpTokenizer
from nltk.tokenize.treebank import TreebankWordTokenizer, TreebankWordDetokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer
import unidecode

STOPWORDS = set(stopwords.words("english"))
# STEMMER = PorterStemmer()
STEMMER = SnowballStemmer("english")
TOKENIZER = RegexpTokenizer('[a-zA-Z0-9]+[a-zA-Z0-9-/]?[a-zA-Z0-9]+|[#$][\d\.]+|[a-z.]+')


def remove_periods_in_acronyms(x):
    """Remove the . in acronyms like d.c. or u.s.a -> dc / usa """
    if re.match('^([a-z][.])+[a-z]?$', x):    
        return x.replace('.', '')
    return x

def remove_hyphens_in_words(x):
    """Remove the hyphen in the middel of a word, like ka-zar -> kazar, x-men -> xmen"""
    if re.match('^[a-z]+[-][a-z]+$', x):    
        return x.replace('-', '')
    return x

print(remove_periods_in_acronyms('a.b'))
    
def tokenize_and_strip_accents(x, phrase_model=None):
    """
    Tokenize the sentence and remove stopwords. 
    Optionally: apply phrase detection with the supplied model
    """
    try:
        norm_string = ' ' + unidecode.unidecode(x).lower() + ' '
    except AttributeError as e:
        norm_string = ' ' + str(x) + ' '
        
    
    #tokenizer = TreebankWordTokenizer()
    words = TOKENIZER.tokenize(norm_string)
    filtered_words = [STEMMER.stem(word) for word in words if word not in STOPWORDS]
    filtered_words = [remove_periods_in_acronyms(word) for word in filtered_words]
    filtered_words = [remove_hyphens_in_words(word) for word in filtered_words]
    if phrase_model:
        return phrase_model[filtered_words]
    return filtered_words

tknzr = TweetTokenizer()
tst = "the citroën ka-zar comic #3423423 Ka-Zar #1 (Jan 1974, Marvel) Comic First Issue Return To The Savage Land dc d.c."
#tknzr.tokenize(str_strip_accents(tst))
tokenize_and_strip_accents(tst)
#[str_strip_accents(accented_string) for accented_string in tknzr.tokenize(tst)]
# Out:
# ab
# ['citroen',
#  'kazar',
#  'comic',
#  '#3423423',
#  'kazar',
#  '#1',
#  'jan',
#  '1974',
#  'marvel',
#  'comic',
#  'first',
#  'issu',
#  'return',
#  'savag',
#  'land',
#  'dc',
#  'dc']

# %%
def trim_path_to_L(path, n):
    split_path = path.split(' > ')
    return ' > '.join(split_path[:n])
    
def dynamic_split_path(path):
    split_path = path.split(' > ')
    n = math.floor(len(split_path)/2)+1
    return ' > '.join(split_path[:n])

def L_minus1_split_path(path):
    split_path = path.split(' > ')
    n = len(split_path)-1
    return ' > '.join(split_path[:n])

print(dynamic_split_path("a > b > c > d"), L_minus1_split_path("a > b > c"), " > ".join("a > b".split(' > ')[:1]))
# Out:
# a > b > c a > b a

# %%
documents['doc'] = documents['title'].apply(lambda x:tokenize_and_strip_accents(x))
# documents['doc_smiple'] = documents['title'].apply(lambda x:simple_preprocess(x))
documents['L1'] = documents['category_breadcrumb'].apply(lambda path: " > ".join(path.split(' > ')[:1]))
documents['L2'] = documents['category_breadcrumb'].apply(lambda path: " > ".join(path.split(' > ')[:2]))
documents['L3'] = documents['category_breadcrumb'].apply(lambda path: " > ".join(path.split(' > ')[:3]))
documents['L4'] = documents['category_breadcrumb'].apply(lambda path: " > ".join(path.split(' > ')[:4]))
documents['L5'] = documents['category_breadcrumb'].apply(lambda path: " > ".join(path.split(' > ')[:5]))
documents['L~'] = documents['category_breadcrumb'].apply(dynamic_split_path)
documents['L-1'] = documents['category_breadcrumb'].apply(L_minus1_split_path)

# %%
from gensim.models.phrases import Phrases, Phraser
#phrase_model = Phrases(documents['doc'], min_count=MIN_WORD_COUNT)
phrase_model = Phrases(documents['doc'], min_count=MIN_WORD_COUNT, scoring='npmi', threshold=0.7)
documents['phrases'] = [phrase_model[words] for words in documents['doc']]
# tokenize_and_strip_accents(documents['title'], phrase_model)
# Out:
# C:\Users\cpieterse\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\models\phrases.py:494: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
X = documents['phrases'] if USE_PHRASES else documents['doc']
y = documents['category_breadcrumb']

# %%
documents.head()
# Out:
#     doc_id   price  \
# 0  1000001  24.95
# 1  1000002  62.95
# 2  1000003  39.99
# 3  1000004  34.39
# 4  1000005  125.00
#
#                                                                               title  \
# 0  CASE CUTLERY Single Blade Pocket Knife USMC MARINES ~ Great Gift
# 1  NYC SUBWAY SIGN NY TRANSIT ART 22X6 238 STREET WHITE PLAINS ROAD BRONX ROLL SIGN
# 2   Disney Store Japan Pin 40695 JDS Face Expressions Stitch Lilo & Stitch
# 3  HOUSTON TEXAS *ICON CITY SERIES 2015* NASA SPACE SHUTTLE OIL Hard Rock Cafe PIN
# 4  *Bottle #2 Prototype/Test Not For Sale Thread H5 Aluminum Coca Cola Bottle Coke
#
#                                                                                                           category_breadcrumb  \
# 0   Collectibles > Knives, Swords & Blades > Collectible Folding Knives > Modern Folding Knives > Factory Manufactured
# 1   Collectibles > Transportation > Subways
# 2   Collectibles > Disneyana > Contemporary (1968-Now) > Pins, Patches & Buttons > Disney Characters & Movies > Lilo & Stitch
# 3   Collectibles > Pinbacks, Bobbles, Lunchboxes > Pinbacks > Restaurant > Hard Rock
# 4   Collectibles > Advertising > Soda > Coca-Cola > Bottles
#
#                                                                         itemid_image_url  \
# 0  https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/0UQAAOSw-2hb7KOd/$_57.JPG?set_id=880000500F
# 1  https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/is8AAOSwTM5Y1m3U/$_1.JPG?set_id=8800005007
# 2  https://i.ebayimg.com/00/s/MTYwMFgxNTIx/z/Au8AAOSwD~Fb5NqB/$_57.JPG?set_id=8800005007
# 3  https://i.ebayimg.com/00/s/MTIwMFgxMDQ2/z/groAAOSwF6dZcCq1/$_57.JPG?set_id=8800005007
# 4  https://i.ebayimg.com/00/s/MTYwMFgxMzUz/z/6w4AAOSw5npckIo2/$_57.JPG?set_id=8800005007
#
#                                                                                                doc  \
# 0  [case, cutleri, singl, blade, pocket, knife, usmc, marin, great, gift]
# 1  [nyc, subway, sign, ny, transit, art, 22x6, 238, street, white, plain, road, bronx, roll, sign]
# 2  [disney, store, japan, pin, 40695, jds, face, express, stitch, lilo, stitch]
# 3  [houston, texa, icon, citi, seri, 2015, nasa, space, shuttl, oil, hard, rock, cafe, pin]
# 4  [bottl, #2, prototype/test, sale, thread, h5, aluminum, coca, cola, bottl, coke]
#
#               L1                                             L2  \
# 0   Collectibles   Collectibles > Knives, Swords & Blades
# 1   Collectibles   Collectibles > Transportation
# 2   Collectibles   Collectibles > Disneyana
# 3   Collectibles   Collectibles > Pinbacks, Bobbles, Lunchboxes
# 4   Collectibles   Collectibles > Advertising
#
#                                                                      L3  \
# 0   Collectibles > Knives, Swords & Blades > Collectible Folding Knives
# 1   Collectibles > Transportation > Subways
# 2   Collectibles > Disneyana > Contemporary (1968-Now)
# 3   Collectibles > Pinbacks, Bobbles, Lunchboxes > Pinbacks
# 4   Collectibles > Advertising > Soda
#
#                                                                                              L4  \
# 0   Collectibles > Knives, Swords & Blades > Collectible Folding Knives > Modern Folding Knives
# 1   Collectibles > Transportation > Subways
# 2   Collectibles > Disneyana > Contemporary (1968-Now) > Pins, Patches & Buttons
# 3   Collectibles > Pinbacks, Bobbles, Lunchboxes > Pinbacks > Restaurant
# 4   Collectibles > Advertising > Soda > Coca-Cola
#
#                                                                                                                     L5  \
# 0   Collectibles > Knives, Swords & Blades > Collectible Folding Knives > Modern Folding Knives > Factory Manufactured
# 1   Collectibles > Transportation > Subways
# 2   Collectibles > Disneyana > Contemporary (1968-Now) > Pins, Patches & Buttons > Disney Characters & Movies
# 3   Collectibles > Pinbacks, Bobbles, Lunchboxes > Pinbacks > Restaurant > Hard Rock
# 4   Collectibles > Advertising > Soda > Coca-Cola > Bottles
#
#                                                                               L~  \
# 0   Collectibles > Knives, Swords & Blades > Collectible Folding Knives
# 1   Collectibles > Transportation
# 2   Collectibles > Disneyana > Contemporary (1968-Now) > Pins, Patches & Buttons
# 3   Collectibles > Pinbacks, Bobbles, Lunchboxes > Pinbacks
# 4   Collectibles > Advertising > Soda
#
#                                                                                                           L-1  \
# 0   Collectibles > Knives, Swords & Blades > Collectible Folding Knives > Modern Folding Knives
# 1   Collectibles > Transportation
# 2   Collectibles > Disneyana > Contemporary (1968-Now) > Pins, Patches & Buttons > Disney Characters & Movies
# 3   Collectibles > Pinbacks, Bobbles, Lunchboxes > Pinbacks > Restaurant
# 4   Collectibles > Advertising > Soda > Coca-Cola
#
#                                                                                           phrases
# 0  [case, cutleri, singl, blade, pocket, knife, usmc, marin, great, gift]
# 1  [nyc_subway, sign, ny, transit, art, 22x6, 238, street, white, plain, road, bronx, roll, sign]
# 2  [disney, store, japan, pin, 40695_jds, face, express, stitch, lilo_stitch]
# 3  [houston, texa, icon, citi, seri, 2015, nasa, space_shuttl, oil, hard, rock, cafe, pin]
# 4  [bottl, #2, prototype/test, sale, thread, h5, aluminum, coca_cola, bottl, coke]

# %%
tokenize_and_strip_accents(['carol', 'carolers', 'caroller'])
# Out:
# ['carol', 'carol', 'carol']

# %% [markdown]
# ## Start training word2vec model from the titles

# %%
import gensim
# let X be a list of tokenized texts (i.e. list of lists of tokens)
model = gensim.models.Word2Vec(X, size=150, min_count=MIN_WORD_COUNT, iter=100)
w2v = dict(zip(model.wv.index2word, model.wv.vectors))

# %%
(model.wv.index2word[0], w2v[model.wv.index2word[0]])
# Out:
# ('vintag',
#  array([ 0.10349678,  1.2065481 , -0.8270068 ,  0.83537453, -0.17647335,
#          0.76849425,  2.1311657 , -0.9952835 , -0.34540427, -1.4363326 ,
#          1.1884595 , -0.6201106 ,  1.5649587 , -0.3137793 ,  1.7367187 ,
#         -1.1559738 , -0.8888798 , -0.8563675 ,  1.9936068 ,  0.04779917,
#          0.7843872 ,  0.5845461 , -3.281599  , -0.17246227,  1.9859278 ,
#          0.5101131 , -0.54196095,  0.45935538,  1.8948755 ,  1.1377028 ,
#          0.09224258, -0.90300417,  3.0093513 ,  0.433184  , -2.168394  ,
#          1.4121349 ,  3.335692  ,  0.25909176, -0.869508  , -1.0435985 ,
#         -1.40455   ,  0.5381693 ,  0.5263063 , -0.28969482,  0.83507365,
#         -0.92838687,  1.0109774 ,  2.3661687 ,  0.5972409 , -1.870957  ,
#          0.07826   ,  0.7922129 ,  1.2302979 , -0.3247182 ,  0.24390344,
#         -1.9556469 , -2.2812812 , -0.7489275 , -0.33463502, -2.2861247 ,
#         -0.22314475,  1.1886561 ,  0.41866302,  1.1520487 , -0.24018112,
#          0.4739796 ,  1.0864992 , -1.2656821 ,  2.3154502 ,  0.61086285,
#         -0.43783888,  0.16382381, -0.52153033, -0.68032175,  1.1291109 ,
#         -0.03034759, -1.1983994 , -0.63175464, -0.7489714 , -0.0735881 ,
#         -0.1505561 ,  1.9749929 , -0.27600735,  3.1312106 ,  0.62579775,
#         -0.04262785,  0.9465213 , -1.3799285 , -1.6818061 , -2.5690017 ,
#          0.99738437, -3.121457  , -0.72976345,  0.49349084,  0.7179305 ,
#         -0.7485624 , -0.20629306,  1.4435579 ,  1.9227031 ,  1.6652526 ,
#          3.3198657 , -1.582266  , -0.30999804,  0.7680313 ,  1.339749  ,
#         -1.3821269 , -0.54702634, -0.20064811,  0.31367067, -1.9128356 ,
#         -0.9921025 , -0.6539842 , -0.6631091 ,  0.16769423, -0.02729119,
#          0.02980522, -0.23659368,  0.827909  ,  0.46275872, -0.5276159 ,
#         -0.10959316, -0.2806482 , -1.7974476 ,  0.90154845,  1.7244962 ,
#         -0.6895801 , -1.0366635 , -1.0629159 , -2.392085  , -0.3863142 ,
#         -0.6301985 , -1.9857464 , -0.23796815,  0.19706288,  1.3228388 ,
#         -2.161262  , -0.10040824, -0.94187945,  1.2366403 , -1.1145597 ,
#          1.0932354 ,  2.0713077 , -0.8679549 ,  1.0407428 ,  0.2752586 ,
#          4.2963924 ,  1.8459874 ,  2.7009676 ,  2.31802   , -0.86181796],
#        dtype=float32))

# %% [markdown]
# ### TfIdf to get IDF information

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
vectorizer = TfidfVectorizer(min_df = MIN_WORD_COUNT
                             , stop_words = stopwords.words('english')
                             , analyzer=lambda x: x)
vectorizer = vectorizer.fit(X)

# %%
idf_weights = {w:vectorizer.idf_[i] for w, i in vectorizer.vocabulary_.items()}

# %% [markdown]
# ### DomCat model using word2vec and the TfIdf model

# %% [markdown]
# Reusing http://nadbordrozd.github.io/blog/2016/05/20/text-classification-with-word2vec/

# %%
import math
import numpy as np
from sklearn.ensemble import ExtraTreesClassifier

class W2VTreeClassifier:
    """Class to combine a W2V and a TfIdf vector and learn a tree directly on the W2V vectors and predict the cagegory"""
    
    # Initialize empty set of class labels
    _class_labels = []
    
    def __init__(self, word_vectors, idf_weights, useLogWeights=True, **kwargs):
        self._word_vectors = word_vectors
        self._idf_weights = idf_weights
        self._useLogWeights = useLogWeights
        self._words = len(self._idf_weights)
        self._log_idf_weights = {
            w:self._idfToLogIdf(idf) for w,idf in self._idf_weights.items()
        }
        self._minIdf = min([w for t,w in self._idf_weights.items()])
        self._minLogIdf = min([w for t,w in self._log_idf_weights.items()])
        self._indexToWord = [w for w,idf in self._idf_weights.items()]
        self._wordToIndex = {w:i for i,w in enumerate(self._indexToWord)}
        self._classifier = ExtraTreesClassifier(min_samples_split=10, **kwargs) #,min_samples_leaf=3,n_estimators=100,bootstrap=True)
        
    def _idfToLogIdf(self, idf):
        """Convert regular IDF value to log representation for better results"""
        df = self._words / idf
        return math.log((self._words + 0.5) / (df + 0.5))
    
    def _get_idf(self, word):
        """Get the (log) IDF of a keyword, or the MIN (log) IDF if it's not found"""
        if word in self._wordToIndex:
            return self._log_idf_weights[word]
        if self._useLogWeights:
            return self._minLogIdf
        return self._minIdf
    
    def _docToVector(self, doc):
        """Convert a document (list of words) to a vector using word2vec"""
        valid_words = [w for w in doc if w in self._word_vectors]
        if len(valid_words) == 0:
            return np.zeros(len(self._word_vectors[self._indexToWord[0]]))
        vec = np.mean([self._word_vectors[w] * self._get_idf(w) for w in valid_words]
                      , axis=0)
        if vec.size <= 1:
            vec = np.zeros(len(self._word_vectors[self._indexToWord[0]]))
        return vec
    
    def _docs_to_vectors(self, X, ignore_empty, y=None):
        """Transform the documents to vectors, optionally ignore empty vectors"""
        vectors = np.array([self._docToVector(doc) for doc in X])
        if not ignore_empty:
            return vectors
        non_zeros = [v.sum() > 0 for v in vectors]
        print("Passed documents: ", np.array([1 for b in non_zeros if b]).sum()
             , " out of: ", vectors.shape[0])
        if y is None:
            return vectors[non_zeros]
        return vectors[non_zeros], np.array(y)[non_zeros]

    def fit(self, X, y, ignore_empty=True):
        """Train the ensemble tree on the train examples in X and class labels in y"""
        train, y = self._docs_to_vectors(X, ignore_empty, y)
        self._classifier = self._classifier.fit(train, y)
        self._class_labels = self._classifier.classes_
        return self

    def predict(self, X):
        """
        Predict the class with the highest probability for every example in X
        """
        test = self._docs_to_vectors(X, False)
        return self._classifier.predict(test)

    def predict_proba(self, X, n=5):
        """
        List the top n ranking class labels per example in X
        Returns: List of sets, with for every item a set with the class label and probability
        """
        if len(self._class_labels) < n:
            n = len(self._class_labels)
        test = self._docs_to_vectors(X, False)
        probabilities = self._classifier.predict_proba(test)
        indexes = np.argsort(-probabilities, axis=1)[:,:n]
        # predictedClasses = self._classes[indexes]
        return [[dict(class_label=self._class_labels[indexes[i,j]]
                      , p=probabilities[i,indexes[i,j]]
                      , rank=j+1)
                 for j in range(n)]
                for i in range(indexes.shape[0])]

    def score(self, X, y, ignore_empty=True):
        """
        Test the model on the documents in X and labels y, 
        Ignore documents that can not be coverted
        """
        test, y = self._docs_to_vectors(X, ignore_empty, y)
        return self._classifier.score(test, y)

# %% [markdown]
# #### Test to get the top N classes

# %%
# classes = w2v_classifier._classifier.classes_
# probabilities = w2v_classifier._classifier.predict_proba([w2v['skywalker'], w2v['ka-zar']])
# indexes = np.argsort(-probabilities, axis=1)[:,:5]

# indexes.shape, classes[indexes]
#np.max(w2v_classifier.predict_log_proba([['vintage']]))
#[[dict(class_label=classes[indexes[i,j]]
#       , p=probabilities[i,indexes[i,j]]
#       , rank=j+1
#      ) for j in range(5)]
#for i in range(indexes.shape[0]) ]

# %% [markdown]
# ### Fit the model

# %%
train_idx = random.sample([i for i in range(len(X))], 400000)

# %%
# Test without phrases
import gc
w2v_classifier = None # Free up memory
gc.collect()
#score = (W2VTreeClassifier(w2v, idf_weights,min_samples_leaf=3,n_estimators=15, bootstrap=True)
# .fit(documents['doc'][train_idx],y[train_idx])
# .score(documents['doc'][10000:20000], y[10000:20000])
#)
gc.collect()
# score
# Out:
# 0

# %%
w2v_classifier = None # Free up memory
gc.collect()
w2v_classifier = (W2VTreeClassifier(w2v, idf_weights,min_samples_leaf=3,n_estimators=15, bootstrap=True)
                  .fit(X[train_idx],y[train_idx]))
w2v_classifier.score(X[10000:20000], y[10000:20000])
# Last run without filterin zeros: 0.6381
# Out:
# Passed documents:  212043  out of:  400000
# Passed documents:  5274  out of:  10000
# 0.6321577550246492

# %%
w2v_classifier.predict([tokenize_and_strip_accents(x, phrase_model if USE_PHRASES else None) 
                        for x in ['sword steel', 'mrs queen mary', 'kazar comic'
                                  , 'ka-zar', 'the coca cola bottles'
                                  , 'harley davidson jacket']])
# Out:
# array([' Collectibles > Tobacciana > Lighters > Other Collectible Lighters',
#        ' Collectibles > Photographic Images > Contemporary (1940-Now) > Other Contemporary Photographs',
#        ' Collectibles > Transportation > Railroadiana & Trains > Paper > Books > 1900-Now',
#        ' Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles',
#        ' Collectibles > Advertising > Soda > Coca-Cola > Bottles',
#        ' Collectibles > Transportation > Motorcycles > American > Harley-Davidson > Other Harley Collectibles'],
#       dtype=object)

# %% [markdown]
# ### Test a bit with the queries

# %%
queries = pd.read_csv(FILES_ROOT_PATH + 'queries.tsv', sep='\t')
queries['terms'] = queries['query'].apply(lambda x: tokenize_and_strip_accents(x, phrase_model if USE_PHRASES else None))
# queries['query'].apply(lambda x:x.split(' '))
queries['DomCat'] = w2v_classifier.predict(queries['terms'])
queries['DomCat_5'] = [json.dumps(labels) for labels in w2v_classifier.predict_proba(queries['terms'],5)]
queries.sample(50)
# Out:
#      query_id                                   query  \
# 4    5         deer sculpture
# 134  135       old fitzgerald
# 11   12        mexico carved wood
# 5    6         usmc
# 67   68        penny machine
# 91   92        angel ornaments
# 84   85        military police patches
# 88   89        absolut vodka bottle
# 124  125       national cash register
# 92   93        piggy piggy banks
# 22   23        glass oil lamp
# 72   73        bullet shot glass
# 110  111       disney bank
# 56   57        breyerfest
# 14   15        wooden radio
# 59   60        cat planter
# 126  127       empty green bottles
# 120  121       large easter eggs
# 3    4         roman replica
# 86   87        ride poster
# 46   47        vintage rotary phone
# 116  117       tea tags
# 121  122       m998 hmmwv
# 113  114       darth vader 3
# 40   41        the walking dead 20
# 53   54        budweiser clydesdale
# 78   79        masonic apron
# 82   83        calif license plates
# 142  143       harley-davidson zippo lighter
# 16   17        stromberg carlson
# 90   91        girl scout books
# 69   70        fence sign
# 28   29        wooden bank
# 122  123       star trek cards
# 135  136       hess truck
# 146  147       bell key chain keyfob
# 149  150       green lantern green arrow comics
# 94   95        goofy phone
# 119  120       michael myers mask
# 109  110       railroad book
# 85   86        white flower pitcher vase
# 10   11        heartwood creek angels
# 132  133       pyramid of giza
# 75   76        wooden tool box
# 106  107       pinball machine
# 6    7         multicam
# 115  116       fire department historical memorabilia
# 61   62        toy steam roller
# 32   33        marvel comics 9.8
# 96   97        sluice
#
#                                      terms  \
# 4    [deer, sculptur]
# 134  [old, fitzgerald]
# 11   [mexico, carv, wood]
# 5    [usmc]
# 67   [penni, machin]
# 91   [angel, ornament]
# 84   [militari, polic, patch]
# 88   [absolut, vodka, bottl]
# 124  [nation, cash, regist]
# 92   [piggi, piggi, bank]
# 22   [glass, oil, lamp]
# 72   [bullet, shot, glass]
# 110  [disney, bank]
# 56   [breyerfest]
# 14   [wooden, radio]
# 59   [cat, planter]
# 126  [empti, green, bottl]
# 120  [larg, easter, egg]
# 3    [roman, replica]
# 86   [ride, poster]
# 46   [vintag, rotari, phone]
# 116  [tea, tag]
# 121  [m998, hmmwv]
# 113  [darth, vader]
# 40   [walk, dead, 20]
# 53   [budweis, clydesdal]
# 78   [mason, apron]
# 82   [calif, licens, plate]
# 142  [harleydavidson, zippo, lighter]
# 16   [stromberg, carlson]
# 90   [girl, scout, book]
# 69   [fenc, sign]
# 28   [wooden, bank]
# 122  [star, trek, card]
# 135  [hess, truck]
# 146  [bell, key, chain, keyfob]
# 149  [green, lantern, green, arrow, comic]
# 94   [goofi, phone]
# 119  [michael, myer, mask]
# 109  [railroad, book]
# 85   [white, flower, pitcher, vase]
# 10   [heartwood, creek, angel]
# 132  [pyramid, giza]
# 75   [wooden, tool, box]
# 106  [pinbal, machin]
# 6    [multicam]
# 115  [fire, depart, histor, memorabilia]
# 61   [toy, steam, roller]
# 32   [marvel, comic, .]
# 96   [sluic]
#
#                                                                                                                 DomCat  \
# 4     Collectibles > Animals > Farm & Countryside > Deer
# 134   Collectibles > Historical Memorabilia > Political > US > Presidents & First Ladies > 1961-63 John F. Kennedy
# 11    Collectibles > Cultures & Ethnicities > Latin American > Mexico > Folk Art
# 5     Collectibles > Militaria > Militaria (Date Unknown) > Marine Corps
# 67    Collectibles > Banks, Registers & Vending > Vending Machines > Gumball
# 91    Collectibles > Holiday & Seasonal > Christmas: Current (1991-Now) > Ornaments > Angels
# 84    Collectibles > Militaria > Current Militaria (2001-Now) > Original Items > Patches > Army
# 88    Collectibles > Advertising > Food & Beverage > Distillery > Absolut
# 124   Collectibles > Banks, Registers & Vending > Cash Registers
# 92    Collectibles > Banks, Registers & Vending > Still, Piggy Banks > Animals > Pigs
# 22    Collectibles > Lamps, Lighting > Lamps: Non-Electric > Kerosene
# 72    Collectibles > Barware > Shot Glasses
# 110   Collectibles > Disneyana > Contemporary (1968-Now) > Banks
# 56    Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles
# 14    Collectibles > Radio, Phonograph, TV, Phone > Radios > Transistor Radios
# 59    Collectibles > Decorative Collectibles > Planters
# 126   Collectibles > Bottles & Insulators > Bottles > Modern (1900-Now) > Sodas
# 120   Collectibles > Holiday & Seasonal > Easter > Current (1991-Now) > Eggs
# 3     Collectibles > Cultures & Ethnicities > Egyptian
# 86    Collectibles > Transportation > Automobilia > Brochures & Catalogs > American Vehicles > Chrysler
# 46    Collectibles > Radio, Phonograph, TV, Phone > Telephones > 1970-Now
# 116   Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles
# 121   Collectibles > Militaria > Surplus > Other Military Surplus
# 113   Collectibles > Science Fiction & Horror > Star Wars > Products, Non-Film Specific > Other Star Wars Collectibles
# 40    Collectibles > Comics > Modern Age (1992-Now) > Horror & Sci-Fi
# 53    Collectibles > Breweriana, Beer > Drinkware, Steins > Glasses > US > Budweiser
# 78    Collectibles > Historical Memorabilia > Fraternal Organizations > Masonic, Freemasonry > Aprons & Regalia
# 82    Collectibles > Transportation > Automobilia > License Plates > US: California
# 142   Collectibles > Tobacciana > Lighters > Zippo > Other Zippo Lighters
# 16    Collectibles > Radio, Phonograph, TV, Phone > Telephones > Pre-1940
# 90    Collectibles > Historical Memorabilia > Fraternal Organizations > Girl Scouts & Girl Guides > Books & Manuals
# 69    Collectibles > Lamps, Lighting > Neon
# 28    Collectibles > Banks, Registers & Vending > Still, Piggy Banks > Other Collectible Still Banks
# 122   Collectibles > Non-Sport Trading Cards > Trading Card Singles
# 135   Collectibles > Advertising > Gas & Oil > Gas & Oil Companies > Hess > 2000-Now
# 146   Collectibles > Pez, Keychains, Promo Glasses > Keychains > Modern (1970-Now)
# 149   Collectibles > Non-Sport Trading Cards > Star Wars Trading Cards > Trading Card Singles
# 94    Collectibles > Disneyana > Contemporary (1968-Now) > Phones
# 119   Collectibles > Arcade, Jukeboxes & Pinball > Arcade Gaming > Replacement Parts
# 109   Collectibles > Transportation > Railroadiana & Trains > Paper > Books > 1900-Now
# 85    Collectibles > Decorative Collectibles > Pitchers
# 10    Collectibles > Decorative Collectibles > Decorative Collectible Brands > Enesco > Jim Shore
# 132   Collectibles > Transportation > Bicycles > Bicycle Accessories
# 75    Collectibles > Tools, Hardware & Locks > Tools > Tool Boxes, Chests
# 106   Collectibles > Arcade, Jukeboxes & Pinball > Pinball > Replacement Parts
# 6     Collectibles > Militaria > Current Militaria (2001-Now) > Original Items > Personal, Field Gear > Pouches
# 115   Collectibles > Historical Memorabilia > Firefighting & Rescue
# 61    Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles
# 32    Collectibles > Pinbacks, Bobbles, Lunchboxes > Bobbleheads, Nodders > Modern (1970-Now) > Funko
# 96    Collectibles > Science & Medicine (1930-Now) > Engineering > Slide Rules
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              DomCat_5
# 4    [{"class_label": " Collectibles > Animals > Farm & Countryside > Deer", "p": 0.11835497835497835, "rank": 1}, {"class_label": " Collectibles > Postcards > US States, Cities & Towns > Illinois", "p": 0.06153846153846154, "rank": 2}, {"class_label": " Collectibles > Decorative Collectibles > Decorative Collectible Brands > Precious Moments > Figurines > Christmas", "p": 0.060000000000000005, "rank": 3}, {"class_label": " Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles", "p": 0.04285714285714285, "rank": 4}, {"class_label": " Collectibles > Decorative Collectibles > Figurines > Animals", "p": 0.04212121212121212, "rank": 5}]
# 134  [{"class_label": " Collectibles > Historical Memorabilia > Political > US > Presidents & First Ladies > 1961-63 John F. Kennedy", "p": 0.06190476190476191, "rank": 1}, {"class_label": " Collectibles > Postcards > US States, Cities & Towns > Virginia", "p": 0.05333333333333334, "rank": 2}, {"class_label": " Collectibles > Advertising > Gas & Oil > Gas & Oil Companies > Hess > 2000-Now", "p": 0.04444444444444444, "rank": 3}, {"class_label": " Collectibles > Breweriana, Beer > Playing Cards", "p": 0.04444444444444444, "rank": 4}, {"class_label": " Collectibles > Historical Memorabilia > Fraternal Organizations > Masonic, Freemasonry > Aprons & Regalia", "p": 0.0375, "rank": 5}]
# 11   [{"class_label": " Collectibles > Cultures & Ethnicities > Latin American > Mexico > Folk Art", "p": 0.13412698412698412, "rank": 1}, {"class_label": " Collectibles > Cultures & Ethnicities > Asian > 1900-Now > Chinese > Figures & Statues", "p": 0.03703703703703704, "rank": 2}, {"class_label": " Collectibles > Tobacciana > Match Holders", "p": 0.03703703703703704, "rank": 3}, {"class_label": " Collectibles > Animals > Other Animal Collectibles", "p": 0.03333333333333333, "rank": 4}, {"class_label": " Collectibles > Souvenirs & Travel Memorabilia > United States > New Jersey", "p": 0.02857142857142857, "rank": 5}]
# 5    [{"class_label": " Collectibles > Militaria > Militaria (Date Unknown) > Marine Corps", "p": 0.10666666666666667, "rank": 1}, {"class_label": " Collectibles > Militaria > Current Militaria (2001-Now) > Original Items > Challenge Coins", "p": 0.09910126910126911, "rank": 2}, {"class_label": " Collectibles > Arcade, Jukeboxes & Pinball > Pinball > Replacement Parts", "p": 0.05454545454545455, "rank": 3}, {"class_label": " Collectibles > Militaria > Current Militaria (2001-Now) > Original Items > Medals & Ribbons", "p": 0.052121212121212124, "rank": 4}, {"class_label": " Collectibles > Paper > Menus", "p": 0.05, "rank": 5}]
# 67   [{"class_label": " Collectibles > Banks, Registers & Vending > Vending Machines > Gumball", "p": 0.2120634920634921, "rank": 1}, {"class_label": " Collectibles > Casino > Slots > Replacement Parts", "p": 0.06666666666666667, "rank": 2}, {"class_label": " Collectibles > Fantasy, Mythical & Magic > Magic > Tricks", "p": 0.06666666666666667, "rank": 3}, {"class_label": " Collectibles > Banks, Registers & Vending > Still, Piggy Banks > Other Collectible Still Banks", "p": 0.05333333333333334, "rank": 4}, {"class_label": " Collectibles > Advertising > Merchandise & Memorabilia > Premiums, Prizes & Charms", "p": 0.0453968253968254, "rank": 5}]
# 91   [{"class_label": " Collectibles > Holiday & Seasonal > Christmas: Current (1991-Now) > Ornaments > Angels", "p": 0.22369454619454618, "rank": 1}, {"class_label": " Collectibles > Decorative Collectibles > Decorative Collectible Brands > Hallmark > Ornaments: by Series > Mary's Angels", "p": 0.10284391534391535, "rank": 2}, {"class_label": " Collectibles > Holiday & Seasonal > Christmas: Current (1991-Now) > Ornaments > Other Current Tree Ornaments", "p": 0.08299015799015799, "rank": 3}, {"class_label": " Collectibles > Decorative Collectibles > Ornaments", "p": 0.06601565101565102, "rank": 4}, {"class_label": " Collectibles > Non-Sport Trading Cards > Wacky Packages > Trading Card Singles", "p": 0.05714285714285714, "rank": 5}]
# 84   [{"class_label": " Collectibles > Militaria > Current Militaria (2001-Now) > Original Items > Patches > Army", "p": 0.16511360099595393, "rank": 1}, {"class_label": " Collectibles > Historical Memorabilia > Police > Patches > International", "p": 0.1343005143005143, "rank": 2}, {"class_label": " Collectibles > Historical Memorabilia > Police > Hats & Caps", "p": 0.10443463943463943, "rank": 3}, {"class_label": " Collectibles > Militaria > Surplus > Patches", "p": 0.10200077700077699, "rank": 4}, {"class_label": " Collectibles > Historical Memorabilia > Police > Other Police Collectibles", "p": 0.04444444444444444, "rank": 5}]
# 88   [{"class_label": " Collectibles > Advertising > Food & Beverage > Distillery > Absolut", "p": 0.13491871962460197, "rank": 1}, {"class_label": " Collectibles > Religion & Spirituality > Christianity > Medals", "p": 0.06666666666666667, "rank": 2}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Radios > Transistor Radios", "p": 0.06666666666666667, "rank": 3}, {"class_label": " Collectibles > Transportation > Bicycles > Bicycle Parts", "p": 0.06666666666666667, "rank": 4}, {"class_label": " Collectibles > Barware > Shot Glasses", "p": 0.03333333333333333, "rank": 5}]
# 124  [{"class_label": " Collectibles > Banks, Registers & Vending > Cash Registers", "p": 0.9486964886964887, "rank": 1}, {"class_label": " Collectibles > Advertising > Computers & High Tech", "p": 0.019047619047619046, "rank": 2}, {"class_label": " Collectibles > Pens & Writing Instruments > Pens > Fountain Pens > Montblanc", "p": 0.01818181818181818, "rank": 3}, {"class_label": " Collectibles > Autographs > Historical", "p": 0.014074074074074074, "rank": 4}, {"class_label": " Collectibles > Advertising > Agriculture", "p": 0.0, "rank": 5}]
# 92   [{"class_label": " Collectibles > Banks, Registers & Vending > Still, Piggy Banks > Animals > Pigs", "p": 0.31990009990009993, "rank": 1}, {"class_label": " Collectibles > Decorative Collectibles > Figurines > Clowns, Circuses", "p": 0.09444444444444446, "rank": 2}, {"class_label": " Collectibles > Banks, Registers & Vending > Still, Piggy Banks > Other Collectible Still Banks", "p": 0.07599021893139539, "rank": 3}, {"class_label": " Collectibles > Banks, Registers & Vending > Still, Piggy Banks > Characters", "p": 0.07371794871794872, "rank": 4}, {"class_label": " Collectibles > Banks, Registers & Vending > Still, Piggy Banks > Animals > Dogs", "p": 0.05555555555555556, "rank": 5}]
# 22   [{"class_label": " Collectibles > Lamps, Lighting > Lamps: Non-Electric > Kerosene", "p": 0.13246031746031747, "rank": 1}, {"class_label": " Collectibles > Lamps, Lighting > Lamps: Electric > Table Lamps", "p": 0.11140452140452141, "rank": 2}, {"class_label": " Collectibles > Lamps, Lighting > Shades", "p": 0.09507936507936508, "rank": 3}, {"class_label": " Collectibles > Lamps, Lighting > Lamps: Non-Electric > Oil", "p": 0.08824074074074074, "rank": 4}, {"class_label": " Collectibles > Lamps, Lighting > Ceiling Fixtures", "p": 0.04975071225071225, "rank": 5}]
# 72   [{"class_label": " Collectibles > Barware > Shot Glasses", "p": 0.06649831649831649, "rank": 1}, {"class_label": " Collectibles > Photographic Images > Contemporary (1940-Now) > Celebrity > Movies", "p": 0.05277777777777778, "rank": 2}, {"class_label": " Collectibles > Transportation > Automobilia > Traffic Lights & Signals", "p": 0.04444444444444444, "rank": 3}, {"class_label": " Collectibles > Pinbacks, Bobbles, Lunchboxes > Pinbacks > Comic Books, Cartoons", "p": 0.04, "rank": 4}, {"class_label": " Collectibles > Religion & Spirituality > Other Spiritual Collectibles", "p": 0.03809523809523809, "rank": 5}]
# 110  [{"class_label": " Collectibles > Disneyana > Contemporary (1968-Now) > Banks", "p": 0.283093573093573, "rank": 1}, {"class_label": " Collectibles > Disneyana > Contemporary (1968-Now) > Plush Toys", "p": 0.05174825174825175, "rank": 2}, {"class_label": " Collectibles > Cultures & Ethnicities > Egyptian", "p": 0.04761904761904762, "rank": 3}, {"class_label": " Collectibles > Disneyana > Contemporary (1968-Now) > Figurines > Winnie the Pooh", "p": 0.04444444444444444, "rank": 4}, {"class_label": " Collectibles > Animation Art & Characters > Animation Characters > Disney", "p": 0.043223443223443216, "rank": 5}]
# 56   [{"class_label": " Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles", "p": 0.06666666666666667, "rank": 1}, {"class_label": " Collectibles > Non-Sport Trading Cards > Vintage Non-Sport Cards", "p": 0.06666666666666667, "rank": 2}, {"class_label": " Collectibles > Kitchen & Home > Kitchenware > Plastic Containers > Contemporary (1970-Now) > Other Plastic Containers", "p": 0.05, "rank": 3}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Radios > Tube Radios > 1930-49", "p": 0.048888888888888885, "rank": 4}, {"class_label": " Collectibles > Decorative Collectibles > Baskets", "p": 0.03703703703703704, "rank": 5}]
# 14   [{"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Radios > Transistor Radios", "p": 0.20353004838298958, "rank": 1}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Radios > Parts & Tubes", "p": 0.1183068783068783, "rank": 2}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Radios > Tube Radios > 1930-49", "p": 0.08085901027077497, "rank": 3}, {"class_label": " Collectibles > Clocks > Modern (1970-Now) > Alarm", "p": 0.06666666666666667, "rank": 4}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Radios > Tube Radios > 1950-59", "p": 0.06581168831168832, "rank": 5}]
# 59   [{"class_label": " Collectibles > Decorative Collectibles > Planters", "p": 0.2870634920634921, "rank": 1}, {"class_label": " Collectibles > Tools, Hardware & Locks > Tools > Carpentry, Woodworking > Planes", "p": 0.060000000000000005, "rank": 2}, {"class_label": " Collectibles > Animals > Cats > Other Cat Collectibles", "p": 0.05, "rank": 3}, {"class_label": " Collectibles > Religion & Spirituality > Buddhism > Other Buddhism Collectibles", "p": 0.04444444444444444, "rank": 4}, {"class_label": " Collectibles > Religion & Spirituality > Buddhism > Statues & Figures", "p": 0.03333333333333333, "rank": 5}]
# 126  [{"class_label": " Collectibles > Bottles & Insulators > Bottles > Modern (1900-Now) > Sodas", "p": 0.05873015873015873, "rank": 1}, {"class_label": " Collectibles > Postcards > Holidays", "p": 0.05714285714285714, "rank": 2}, {"class_label": " Collectibles > Kitchen & Home > Kitchenware > Plastic Containers > Contemporary (1970-Now) > Other Plastic Containers", "p": 0.04666666666666666, "rank": 3}, {"class_label": " Collectibles > Bottles & Insulators > Bottles > Modern (1900-Now) > Liquor", "p": 0.04349206349206349, "rank": 4}, {"class_label": " Collectibles > Advertising > Food & Beverage > Distillery > Other Distillery Ads", "p": 0.04, "rank": 5}]
# 120  [{"class_label": " Collectibles > Holiday & Seasonal > Easter > Current (1991-Now) > Eggs", "p": 0.18257936507936506, "rank": 1}, {"class_label": " Collectibles > Postcards > Holidays", "p": 0.1674074074074074, "rank": 2}, {"class_label": " Collectibles > Holiday & Seasonal > Easter > Current (1991-Now) > Bunnies, Rabbits", "p": 0.12666666666666668, "rank": 3}, {"class_label": " Collectibles > Holiday & Seasonal > Easter > Modern (1960-1990) > Bunnies, Rabbits", "p": 0.08407407407407406, "rank": 4}, {"class_label": " Collectibles > Holiday & Seasonal > Easter > Vintage (Pre-1960) > Eggs", "p": 0.05, "rank": 5}]
# 3    [{"class_label": " Collectibles > Historical Memorabilia > Royalty > Princess Diana", "p": 0.06666666666666667, "rank": 1}, {"class_label": " Collectibles > Cultures & Ethnicities > Egyptian", "p": 0.06666666666666667, "rank": 2}, {"class_label": " Collectibles > Knives, Swords & Blades > Armor & Shields", "p": 0.06055555555555556, "rank": 3}, {"class_label": " Collectibles > Animals > Horses: Model Horses > Trail of Painted Ponies", "p": 0.05238095238095238, "rank": 4}, {"class_label": " Collectibles > Decorative Collectibles > Decorative Collectible Brands > Precious Moments > Figurines > Other Precious Moments Figures", "p": 0.048484848484848485, "rank": 5}]
# 86   [{"class_label": " Collectibles > Transportation > Automobilia > Brochures & Catalogs > American Vehicles > Chrysler", "p": 0.06666666666666667, "rank": 1}, {"class_label": " Collectibles > Science & Medicine (1930-Now) > Engineering > Slide Rules", "p": 0.05, "rank": 2}, {"class_label": " Collectibles > Transportation > Bicycles > Bicycle Parts", "p": 0.04615384615384615, "rank": 3}, {"class_label": " Collectibles > Postcards > Holidays", "p": 0.04444444444444444, "rank": 4}, {"class_label": " Collectibles > Photographic Images > Contemporary (1940-Now) > Celebrity > Movies", "p": 0.04285714285714285, "rank": 5}]
# 46   [{"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Telephones > 1970-Now", "p": 0.7677777777777777, "rank": 1}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Telephones > 1940-69", "p": 0.15119047619047618, "rank": 2}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Telephones > Pre-1940", "p": 0.015000000000000001, "rank": 3}, {"class_label": " Collectibles > Advertising > Gas & Oil > Merchandise & Memorabilia > Cans & Buckets", "p": 0.009523809523809523, "rank": 4}, {"class_label": " Collectibles > Animation Art & Characters > Animation Characters > Disney", "p": 0.009523809523809523, "rank": 5}]
# 116  [{"class_label": " Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles", "p": 0.05666666666666667, "rank": 1}, {"class_label": " Collectibles > Militaria > Current Militaria (2001-Now) > Original Items > Uniforms", "p": 0.05555555555555556, "rank": 2}, {"class_label": " Collectibles > Non-Sport Trading Cards > Star Trek Trading Cards > Trading Card Singles", "p": 0.05, "rank": 3}, {"class_label": " Collectibles > Animals > Insects & Butterflies > Butterflies & Moths", "p": 0.05, "rank": 4}, {"class_label": " Collectibles > Lamps, Lighting > Lamp Repair, Refurbishing > Parts", "p": 0.03809523809523809, "rank": 5}]
# 121  [{"class_label": " Collectibles > Militaria > Surplus > Other Military Surplus", "p": 0.6437830687830688, "rank": 1}, {"class_label": " Collectibles > Cultures & Ethnicities > Asian > 1900-Now > Japanese > Kimonos", "p": 0.03333333333333333, "rank": 2}, {"class_label": " Collectibles > Postcards > US States, Cities & Towns > Massachusetts", "p": 0.03333333333333333, "rank": 3}, {"class_label": " Collectibles > Decorative Collectibles > Music Boxes > 1940-1970", "p": 0.02857142857142857, "rank": 4}, {"class_label": " Collectibles > Decorative Collectibles > Decorative Collectible Brands > Hallmark > Ornaments: by Year > 1980-84", "p": 0.02857142857142857, "rank": 5}]
# 113  [{"class_label": " Collectibles > Science Fiction & Horror > Star Wars > Products, Non-Film Specific > Other Star Wars Collectibles", "p": 0.32734143049932524, "rank": 1}, {"class_label": " Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles", "p": 0.0857142857142857, "rank": 2}, {"class_label": " Collectibles > Pinbacks, Bobbles, Lunchboxes > Bobbleheads, Nodders > Modern (1970-Now) > Funko", "p": 0.08333333333333333, "rank": 3}, {"class_label": " Collectibles > Animation Art & Characters > Japanese, Anime > Saint Seiya", "p": 0.05333333333333334, "rank": 4}, {"class_label": " Collectibles > Science Fiction & Horror > Star Wars > Products, Non-Film Specific > Statues, Busts, Characters > Other Star Wars Characters", "p": 0.04761904761904762, "rank": 5}]
# 40   [{"class_label": " Collectibles > Comics > Modern Age (1992-Now) > Horror & Sci-Fi", "p": 0.18700980392156863, "rank": 1}, {"class_label": " Collectibles > Pinbacks, Bobbles, Lunchboxes > Bobbleheads, Nodders > Modern (1970-Now) > Funko", "p": 0.11137254901960784, "rank": 2}, {"class_label": " Collectibles > Lamps, Lighting > Lamps: Non-Electric > Oil", "p": 0.05, "rank": 3}, {"class_label": " Collectibles > Militaria > WW II (1939-45) > Original Period Items > United States > Home Front", "p": 0.041025641025641026, "rank": 4}, {"class_label": " Collectibles > Transportation > Signs", "p": 0.04, "rank": 5}]
# 53   [{"class_label": " Collectibles > Breweriana, Beer > Drinkware, Steins > Glasses > US > Budweiser", "p": 0.14142450142450141, "rank": 1}, {"class_label": " Collectibles > Breweriana, Beer > Signs & Tins > Budweiser", "p": 0.13884615384615387, "rank": 2}, {"class_label": " Collectibles > Lamps, Lighting > Neon", "p": 0.058333333333333334, "rank": 3}, {"class_label": " Collectibles > Breweriana, Beer > Drinkware, Steins > Steins > US", "p": 0.05407407407407407, "rank": 4}, {"class_label": " Collectibles > Breweriana, Beer > Other Breweriana", "p": 0.045014245014245016, "rank": 5}]
# 78   [{"class_label": " Collectibles > Historical Memorabilia > Fraternal Organizations > Masonic, Freemasonry > Aprons & Regalia", "p": 0.5083338247579733, "rank": 1}, {"class_label": " Collectibles > Historical Memorabilia > Fraternal Organizations > Order of the Eastern Star", "p": 0.06494708994708993, "rank": 2}, {"class_label": " Collectibles > Kitchen & Home > Kitchenware > Utensils > Egg Beaters", "p": 0.059259259259259255, "rank": 3}, {"class_label": " Collectibles > Vintage, Retro, Mid-Century > Bakelite", "p": 0.03333333333333333, "rank": 4}, {"class_label": " Collectibles > Non-Sport Trading Cards > Star Wars Trading Cards > Trading Card Singles", "p": 0.03333333333333333, "rank": 5}]
# 82   [{"class_label": " Collectibles > Transportation > Automobilia > License Plates > US: California", "p": 0.3777777777777777, "rank": 1}, {"class_label": " Collectibles > Transportation > Automobilia > License Plates > Other US License Plates", "p": 0.1068013468013468, "rank": 2}, {"class_label": " Collectibles > Transportation > Automobilia > License Plates > US: Florida", "p": 0.0709090909090909, "rank": 3}, {"class_label": " Collectibles > Transportation > Automobilia > License Plates > US: Michigan", "p": 0.04069264069264069, "rank": 4}, {"class_label": " Collectibles > Transportation > Automobilia > License Plates > US: Illinois", "p": 0.03777777777777778, "rank": 5}]
# 142  [{"class_label": " Collectibles > Tobacciana > Lighters > Zippo > Other Zippo Lighters", "p": 0.5361243386243386, "rank": 1}, {"class_label": " Collectibles > Tobacciana > Lighters > Zippo > Motorcycles", "p": 0.1307142857142857, "rank": 2}, {"class_label": " Collectibles > Tobacciana > Lighters > Other Collectible Lighters", "p": 0.047407407407407405, "rank": 3}, {"class_label": " Collectibles > Tobacciana > Price Guides & Publications", "p": 0.04126984126984127, "rank": 4}, {"class_label": " Collectibles > Tobacciana > Lighters > Zippo > Cigarettes", "p": 0.04031746031746032, "rank": 5}]
# 16   [{"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Telephones > Pre-1940", "p": 0.15812576312576312, "rank": 1}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Telephones > 1970-Now", "p": 0.12356735856735858, "rank": 2}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Telephones > 1940-69", "p": 0.0765079365079365, "rank": 3}, {"class_label": " Collectibles > Casino > Card Shuffler", "p": 0.06666666666666667, "rank": 4}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Phonographs, Accessories > Other Phonographs", "p": 0.04126984126984127, "rank": 5}]
# 90   [{"class_label": " Collectibles > Historical Memorabilia > Fraternal Organizations > Girl Scouts & Girl Guides > Books & Manuals", "p": 0.3987617937617937, "rank": 1}, {"class_label": " Collectibles > Historical Memorabilia > Fraternal Organizations > Girl Scouts & Girl Guides > Badges & Patches", "p": 0.15474266474266474, "rank": 2}, {"class_label": " Collectibles > Historical Memorabilia > Fraternal Organizations > Boy Scouts > Books & Manuals", "p": 0.08026529026529028, "rank": 3}, {"class_label": " Collectibles > Historical Memorabilia > Fraternal Organizations > Girl Scouts & Girl Guides > Other Girl Scout Collectibles", "p": 0.04725108225108225, "rank": 4}, {"class_label": " Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles", "p": 0.03428571428571428, "rank": 5}]
# 69   [{"class_label": " Collectibles > Lamps, Lighting > Neon", "p": 0.06222222222222222, "rank": 1}, {"class_label": " Collectibles > Transportation > Automobilia > License Plate Frames", "p": 0.06111111111111111, "rank": 2}, {"class_label": " Collectibles > Advertising > Merchandise & Memorabilia > Signs > Original > 1970-Now", "p": 0.051666666666666666, "rank": 3}, {"class_label": " Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles", "p": 0.043137254901960784, "rank": 4}, {"class_label": " Collectibles > Postcards > Holidays", "p": 0.03796296296296296, "rank": 5}]
# 28   [{"class_label": " Collectibles > Banks, Registers & Vending > Still, Piggy Banks > Other Collectible Still Banks", "p": 0.08087542087542086, "rank": 1}, {"class_label": " Collectibles > Postcards > US States, Cities & Towns > Illinois", "p": 0.06666666666666667, "rank": 2}, {"class_label": " Collectibles > Postcards > Holidays", "p": 0.06666666666666667, "rank": 3}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Radios > Tube Radios > 1930-49", "p": 0.05555555555555556, "rank": 4}, {"class_label": " Collectibles > Banks, Registers & Vending > Mechanical Banks", "p": 0.046296296296296294, "rank": 5}]
# 122  [{"class_label": " Collectibles > Non-Sport Trading Cards > Trading Card Singles", "p": 0.3868013468013468, "rank": 1}, {"class_label": " Collectibles > Non-Sport Trading Cards > Star Trek Trading Cards > Trading Card Singles", "p": 0.12835016835016835, "rank": 2}, {"class_label": " Collectibles > Non-Sport Trading Cards > Star Wars Trading Cards > Trading Card Singles", "p": 0.09666666666666668, "rank": 3}, {"class_label": " Collectibles > Science Fiction & Horror > X-Files", "p": 0.06666666666666667, "rank": 4}, {"class_label": " Collectibles > Militaria > Surplus > Other Military Surplus", "p": 0.05333333333333334, "rank": 5}]
# 135  [{"class_label": " Collectibles > Advertising > Gas & Oil > Gas & Oil Companies > Hess > 2000-Now", "p": 0.23717171717171717, "rank": 1}, {"class_label": " Collectibles > Advertising > Gas & Oil > Gas & Oil Companies > Hess > 1990-94", "p": 0.11173160173160174, "rank": 2}, {"class_label": " Collectibles > Advertising > Gas & Oil > Gas & Oil Companies > Hess > 1995-99", "p": 0.09506493506493506, "rank": 3}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Radios > Manuals", "p": 0.06666666666666667, "rank": 4}, {"class_label": " Collectibles > Postcards > Transportation > Trains, Railroad", "p": 0.06666666666666667, "rank": 5}]
# 146  [{"class_label": " Collectibles > Pez, Keychains, Promo Glasses > Keychains > Modern (1970-Now)", "p": 0.14730158730158732, "rank": 1}, {"class_label": " Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles", "p": 0.10549450549450551, "rank": 2}, {"class_label": " Collectibles > Tools, Hardware & Locks > Locks, Keys", "p": 0.08952380952380952, "rank": 3}, {"class_label": " Collectibles > Tobacciana > Match Holders", "p": 0.05317460317460318, "rank": 4}, {"class_label": " Collectibles > Disneyana > Contemporary (1968-Now) > Pins, Patches & Buttons > Other Disney Pins & Patches", "p": 0.04786324786324787, "rank": 5}]
# 149  [{"class_label": " Collectibles > Non-Sport Trading Cards > Star Wars Trading Cards > Trading Card Singles", "p": 0.06806439747616218, "rank": 1}, {"class_label": " Collectibles > Postcards > US States, Cities & Towns > Illinois", "p": 0.06666666666666667, "rank": 2}, {"class_label": " Collectibles > Non-Sport Trading Cards > Trading Card Singles", "p": 0.06397306397306397, "rank": 3}, {"class_label": " Collectibles > Comics > Modern Age (1992-Now) > Superhero > Other Modern Age Superheroes", "p": 0.04, "rank": 4}, {"class_label": " Collectibles > Science Fiction & Horror > Star Wars > Products, Non-Film Specific > Other Star Wars Collectibles", "p": 0.03809523809523809, "rank": 5}]
# 94   [{"class_label": " Collectibles > Disneyana > Contemporary (1968-Now) > Phones", "p": 0.17154040404040405, "rank": 1}, {"class_label": " Collectibles > Disneyana > Contemporary (1968-Now) > Banks", "p": 0.155959595959596, "rank": 2}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Telephones > 1970-Now", "p": 0.11392385392385393, "rank": 3}, {"class_label": " Collectibles > Advertising > Soda > Coca-Cola > Cookie Jars & Canisters", "p": 0.05, "rank": 4}, {"class_label": " Collectibles > Disneyana > Vintage (Pre-1968) > Other Vintage Disneyana", "p": 0.042222222222222223, "rank": 5}]
# 119  [{"class_label": " Collectibles > Arcade, Jukeboxes & Pinball > Arcade Gaming > Replacement Parts", "p": 0.06666666666666667, "rank": 1}, {"class_label": " Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles", "p": 0.05878787878787879, "rank": 2}, {"class_label": " Collectibles > Knives, Swords & Blades > Armor & Shields", "p": 0.05714285714285714, "rank": 3}, {"class_label": " Collectibles > Tools, Hardware & Locks > Tools > Carpentry, Woodworking > Axes, Hatchets", "p": 0.04444444444444444, "rank": 4}, {"class_label": " Collectibles > Decorative Collectibles > Music Boxes > 1970-Now", "p": 0.043333333333333335, "rank": 5}]
# 109  [{"class_label": " Collectibles > Transportation > Railroadiana & Trains > Paper > Books > 1900-Now", "p": 0.43828282828282833, "rank": 1}, {"class_label": " Collectibles > Non-Sport Trading Cards > Sticker Albums, Packs & Spares", "p": 0.06666666666666667, "rank": 2}, {"class_label": " Collectibles > Transportation > Railroadiana & Trains > Other Railroadiana", "p": 0.042727272727272725, "rank": 3}, {"class_label": " Collectibles > Transportation > Railroadiana & Trains > Paper > Employee Timetables", "p": 0.04090909090909091, "rank": 4}, {"class_label": " Collectibles > Transportation > Railroadiana & Trains > Paper > Rule Books", "p": 0.04000000000000001, "rank": 5}]
# 85   [{"class_label": " Collectibles > Decorative Collectibles > Pitchers", "p": 0.20684343434343433, "rank": 1}, {"class_label": " Collectibles > Decorative Collectibles > Vases", "p": 0.1923929773929774, "rank": 2}, {"class_label": " Collectibles > Photographic Images > Contemporary (1940-Now) > Celebrity > Sports", "p": 0.04444444444444444, "rank": 3}, {"class_label": " Collectibles > Decorative Collectibles > Eggs", "p": 0.03857142857142857, "rank": 4}, {"class_label": " Collectibles > Advertising > Food & Beverage > Distillery > Seagrams", "p": 0.02666666666666667, "rank": 5}]
# 10   [{"class_label": " Collectibles > Decorative Collectibles > Decorative Collectible Brands > Enesco > Jim Shore", "p": 0.5418518518518518, "rank": 1}, {"class_label": " Collectibles > Decorative Collectibles > Decorative Collectible Brands > Royal Doulton > Figurines", "p": 0.06666666666666667, "rank": 2}, {"class_label": " Collectibles > Decorative Collectibles > Music Boxes > 1970-Now", "p": 0.0392156862745098, "rank": 3}, {"class_label": " Collectibles > Holiday & Seasonal > Easter > Current (1991-Now) > Bunnies, Rabbits", "p": 0.03747276688453159, "rank": 4}, {"class_label": " Collectibles > Advertising > Food & Beverage > Distillery > Absolut", "p": 0.03703703703703704, "rank": 5}]
# 132  [{"class_label": " Collectibles > Transportation > Bicycles > Bicycle Accessories", "p": 0.06666666666666667, "rank": 1}, {"class_label": " Collectibles > Rocks, Fossils & Minerals > Crystals & Mineral Specimens > Crystals", "p": 0.05333333333333334, "rank": 2}, {"class_label": " Collectibles > Tobacciana > Cigars > Grinders", "p": 0.05185185185185185, "rank": 3}, {"class_label": " Collectibles > Transportation > Railroadiana & Trains > Paper > Manuals & Guides", "p": 0.03703703703703704, "rank": 4}, {"class_label": " Collectibles > Science Fiction & Horror > Star Trek > Deep Space Nine", "p": 0.03333333333333333, "rank": 5}]
# 75   [{"class_label": " Collectibles > Tools, Hardware & Locks > Tools > Tool Boxes, Chests", "p": 0.14383838383838382, "rank": 1}, {"class_label": " Collectibles > Tools, Hardware & Locks > Tools > Carpentry, Woodworking > Drills", "p": 0.05462121212121212, "rank": 2}, {"class_label": " Collectibles > Advertising > Gas & Oil > Gas & Oil Companies > Hess > 2000-Now", "p": 0.05454545454545455, "rank": 3}, {"class_label": " Collectibles > Banks, Registers & Vending > Cash Registers", "p": 0.05, "rank": 4}, {"class_label": " Collectibles > Tools, Hardware & Locks > Tools > Other Collectible Tools", "p": 0.04962121212121213, "rank": 5}]
# 106  [{"class_label": " Collectibles > Arcade, Jukeboxes & Pinball > Pinball > Replacement Parts", "p": 0.5163612313612314, "rank": 1}, {"class_label": " Collectibles > Arcade, Jukeboxes & Pinball > Pinball > Machines", "p": 0.09915584415584415, "rank": 2}, {"class_label": " Collectibles > Arcade, Jukeboxes & Pinball > Pinball > Manuals & Guides", "p": 0.09253968253968253, "rank": 3}, {"class_label": " Collectibles > Banks, Registers & Vending > Vending Machines > Gumball", "p": 0.08148148148148149, "rank": 4}, {"class_label": " Collectibles > Arcade, Jukeboxes & Pinball > Other Coin-Op Collectibles", "p": 0.03333333333333333, "rank": 5}]
# 6    [{"class_label": " Collectibles > Militaria > Current Militaria (2001-Now) > Original Items > Personal, Field Gear > Pouches", "p": 0.17418894830659537, "rank": 1}, {"class_label": " Collectibles > Militaria > Current Militaria (2001-Now) > Original Items > Uniforms", "p": 0.16507936507936508, "rank": 2}, {"class_label": " Collectibles > Militaria > Current Militaria (2001-Now) > Original Items > Personal, Field Gear > Bags & Packs", "p": 0.10855614973262033, "rank": 3}, {"class_label": " Collectibles > Militaria > Current Militaria (2001-Now) > Original Items > Personal, Field Gear > Other Current Field Gear", "p": 0.07281045751633987, "rank": 4}, {"class_label": " Collectibles > Animation Art & Characters > Japanese, Anime > DragonBall Z", "p": 0.06666666666666667, "rank": 5}]
# 115  [{"class_label": " Collectibles > Historical Memorabilia > Firefighting & Rescue", "p": 0.13526936026936026, "rank": 1}, {"class_label": " Collectibles > Historical Memorabilia > Other Historical Memorabilia", "p": 0.10942760942760943, "rank": 2}, {"class_label": " Collectibles > Historical Memorabilia > Firefighting & Rescue > Patches > U.S.", "p": 0.07222222222222223, "rank": 3}, {"class_label": " Collectibles > Cultures & Ethnicities > Australian", "p": 0.0659090909090909, "rank": 4}, {"class_label": " Collectibles > Linens & Textiles (1930-Now) > Bed & Bath Linens > Blankets", "p": 0.059259259259259255, "rank": 5}]
# 61   [{"class_label": " Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles", "p": 0.07619047619047618, "rank": 1}, {"class_label": " Collectibles > Animation Art & Characters > Japanese, Anime > DragonBall Z", "p": 0.06190476190476191, "rank": 2}, {"class_label": " Collectibles > Radio, Phonograph, TV, Phone > Radios > Transistor Radios", "p": 0.058333333333333334, "rank": 3}, {"class_label": " Collectibles > Militaria > Surplus > Other Military Surplus", "p": 0.05333333333333334, "rank": 4}, {"class_label": " Collectibles > Disneyana > Contemporary (1968-Now) > Other Disneyana", "p": 0.03809523809523809, "rank": 5}]
# 32   [{"class_label": " Collectibles > Pinbacks, Bobbles, Lunchboxes > Bobbleheads, Nodders > Modern (1970-Now) > Funko", "p": 0.0846153846153846, "rank": 1}, {"class_label": " Collectibles > Non-Sport Trading Cards > Vintage Non-Sport Cards", "p": 0.07445887445887446, "rank": 2}, {"class_label": " Collectibles > Non-Sport Trading Cards > Other Non-Sport Card Merch", "p": 0.0620979020979021, "rank": 3}, {"class_label": " Collectibles > Non-Sport Trading Cards > Trading Card Singles", "p": 0.05187257187257187, "rank": 4}, {"class_label": " Collectibles > Comics > Modern Age (1992-Now) > Superhero > Other Modern Age Superheroes", "p": 0.04666666666666666, "rank": 5}]
# 96   [{"class_label": " Collectibles > Science & Medicine (1930-Now) > Engineering > Slide Rules", "p": 0.06666666666666667, "rank": 1}, {"class_label": " Collectibles > Non-Sport Trading Cards > Game of Thrones Trading Cards > Trading Card Singles", "p": 0.048888888888888885, "rank": 2}, {"class_label": " Collectibles > Arcade, Jukeboxes & Pinball > Arcade Gaming > Other Arcade Gaming", "p": 0.048484848484848485, "rank": 3}, {"class_label": " Collectibles > Photographic Images > Contemporary (1940-Now) > Other Contemporary Photographs", "p": 0.04686147186147186, "rank": 4}, {"class_label": " Collectibles > Metalware > Cast Iron", "p": 0.04, "rank": 5}]

# %%
queries.to_csv(FILES_ROOT_PATH + 'queries_with_labels.tsv', sep='\t', encoding='utf-8')

# %%
exploded_domcat = pd.DataFrame([(r['query'], labels['class_label'], labels['p'])
                                for i,r in queries.iterrows()
                                for labels in json.loads(r['DomCat_5'])
                               ], columns=['query', 'category_breadcrumb', 'score'])
exploded_domcat.to_csv(FILES_ROOT_PATH + 'queries_with_domcat_5.tsv', sep='\t', encoding='utf-8')
exploded_domcat.head()
# Out:
#          query  \
# 0  kazar comic
# 1  kazar comic
# 2  kazar comic
# 3  kazar comic
# 4  kazar comic
#
#                                                                                              category_breadcrumb  \
# 0   Collectibles > Transportation > Railroadiana & Trains > Paper > Books > 1900-Now
# 1   Collectibles > Animation Art & Characters > Japanese, Anime > Other Anime Collectibles
# 2   Collectibles > Historical Memorabilia > Political > US > Presidents & First Ladies > 1961-63 John F. Kennedy
# 3   Collectibles > Sewing (1930-Now) > Spools & Thread
# 4   Collectibles > Radio, Phonograph, TV, Phone > Radios > Transistor Radios
#
#       score
# 0  0.086667
# 1  0.070833
# 2  0.068889
# 3  0.053333
# 4  0.033333

# %% [markdown]
# ### Synoyms for the queries

# %%
query_terms = set([term for terms in queries.terms for term in terms])
synonyms = pd.DataFrame([(word, match[0], match[1]) 
            #for word in model.wv.index2word 
                         for word in query_terms
            for match in model.wv.most_similar(word) if match[1] > MIN_SIMILARITY_FOR_SYNONYMS]
                        , columns=['word', 'synonym', 'similarity'])
    
synonyms[0:20]
# Out:
#         word    synonym  similarity
# 0   gnome     cairn      0.736252
# 1   grinder   herb       0.722598
# 2   zippo     lighter    0.723830
# 3   cgc       cbcs       0.879096
# 4   vader     vadar      0.735752
# 5   vader     maul       0.735582
# 6   vader     sidious    0.724600
# 7   hmmwv     m998       0.911901
# 8   hmmwv     m1151      0.701889
# 9   precious  prescious  0.784125
# 10  hexagon   octagon    0.808609
# 11  phone     telephon   0.846273
# 12  tole      tolewar    0.750475
# 13  illinoi   il         0.813933
# 14  15        14         0.826682
# 15  15        17         0.812658
# 16  15        13         0.811642
# 17  15        19         0.807860
# 18  15        18         0.775452
# 19  15        20         0.773990

# %%
#pd.DataFrame([json.dumps(s) for s in synonyms], columns=['synonyms']).to_csv(FILES_ROOT_PATH + 'synonyms_90.csv')
synonyms.to_csv(FILES_ROOT_PATH + 'synonyms_80.csv')

# %%
word_to_cluster, cluster_to_synonyms = collapse_synonyms(synonyms, 'word', 'synonym')

# %%
syns_for_output = [','.join([e for e in synset if not re.match('^[#a-z]?[0-9]+|[0-9]+[a-z]?[a-z]?$', e)]) 
                   for k,synset in cluster_to_synonyms.items()]
pd.DataFrame([synset for synset in syns_for_output if synset and ',' in synset]
             , columns=['flat_synonyms']).to_csv(FILES_ROOT_PATH + 'flat_synonyms.txt'
                    , index_label=False
                    , index=False
                    , header=False
                    , quoting = csv.QUOTE_NONE
                    , sep='|'
                    , quotechar="",  escapechar="\\"
                    , columns=['flat_synonyms']
                    , encoding='UTF8')

# %% [markdown]
# #### Loop it together to create different category level predictions

# %%
train_idx = random.sample([i for i in range(len(X))], 800000)
levels = ['category_breadcrumb', 'L1', 'L2', 'L3', 'L4', 'L5', 'L~', 'L-1']
# levels = ['L5', 'L~', 'L-1']
w2v_classifier = None # Free up memory
gc.collect()
w2v_classifier = W2VTreeClassifier(w2v, idf_weights,min_samples_leaf=3,n_estimators=15, bootstrap=True)
# Last run without filterin zeros: 0.6381
for ilevel, level in enumerate(levels):
    Y = documents[level]
    print(level)
    w2v_classifier = w2v_classifier.fit(X[train_idx],Y[train_idx])
    columnName = 'DomCat_10_' + level
    queries[columnName] = [json.dumps(labels) for labels in w2v_classifier.predict_proba(queries['terms'],10)]
    print("Score at level {}: {}".format(level, w2v_classifier.score(X[10000:20000], Y[10000:20000])))
    
    # Write column to separate file
    exploded_domcat = pd.DataFrame([(r['query'], labels['class_label'], labels['p'])
                                for i,r in queries.iterrows()
                                for labels in json.loads(r[columnName])
                               ], columns=['query', level, 'score'])
    exploded_domcat.to_csv(FILES_ROOT_PATH + 'queries_with_' + columnName.replace('~', '_') + '.tsv'
                           , sep='\t', encoding='utf-8')

queries.to_csv(FILES_ROOT_PATH + 'queries_with_labels.tsv', sep='\t', encoding='utf-8')
# Out:
# category_breadcrumb
# Passed documents:  211898  out of:  400000
# Passed documents:  5274  out of:  10000
# Score at level category_breadcrumb: 0.6414486158513463
# L1
# Passed documents:  211898  out of:  400000
# Passed documents:  5274  out of:  10000
# Score at level L1: 1.0
# L2
# Passed documents:  211898  out of:  400000
# Passed documents:  5274  out of:  10000
# Score at level L2: 0.7950322335987865
# L3
# Passed documents:  211898  out of:  400000
# Passed documents:  5274  out of:  10000
# Score at level L3: 0.7178612059158134
# L4
# Passed documents:  211898  out of:  400000
# Passed documents:  5274  out of:  10000
# Score at level L4: 0.6710276829730755
# L5
# Passed documents:  211898  out of:  400000
# Passed documents:  5274  out of:  10000
# Score at level L5: 0.643344709897611
# L~
# Passed documents:  211898  out of:  400000
# Passed documents:  5274  out of:  10000
# Score at level L~: 0.7237390974592339
# L-1
# Passed documents:  211898  out of:  400000
# Passed documents:  5274  out of:  10000
# Score at level L-1: 0.6998483124762989

# %%
levels = ['category_breadcrumb', 'L1', 'L2', 'L3', 'L4', 'L5', 'L~', 'L-1']

for level in levels:
    columnName = 'DomCat_10_' + level
    exploded_domcat = pd.DataFrame([(r['query'], labels['class_label'], labels['p'])
                                for i,r in queries.iterrows()
                                for labels in json.loads(r[columnName])
                               ], columns=['query', level, 'score'])
    exploded_domcat.to_csv(FILES_ROOT_PATH + 'queries_with_' + columnName.replace('~', '_') + '.tsv'
                           , sep='\t', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c2f11acd7d30> in <module>()
#       3 for level in levels:
#       4     columnName = 'DomCat_10_' + level
# ----> 5     exploded_domcat = pd.DataFrame([(r['query'], labels['class_label'], labels['p'])
#       6                                 for i,r in queries.iterrows()
#       7                                 for labels in json.loads(r[columnName])
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Work in progress

# %%
import elasticsearch

# %%
queries

# %%
# if a word was never seen - it must be at least as infrequent
# as any of the known words - so the default idf is the max of 
# known idf's
max_idf = max(vectorizer.idf_)

# %%
#classifier = classifier.fit(doc_vectors[0:10000],y[0:10000])

# %%
import math
from scipy import sparse

class TfIdfTreeClassifier:
    """Class to construct a TfIdf vector and learn tree directly on the input vectors"""
    
    def __init__(self, idf_weights, useLogWeights=True):
        self._idf_weights = idf_weights
        self._useLogWeights = useLogWeights
        self._words = len(self._idf_weights)
        self._log_idf_weights = {
            w:self._idfToLogIdf(idf) for w,idf in self._idf_weights.items()
        }
        self._maxIdf = max([w for t,w in self._idf_weights.items()])
        self._maxLogIdf = max([w for t,w in self._log_idf_weights.items()])
        self._indexToWord = [w for w,idf in self._idf_weights.items()]
        self._wordToIndex = {w:i for i,w in enumerate(self._indexToWord)}
        self._classifier = ExtraTreesClassifier(min_samples_split=10,min_samples_leaf=3,n_estimators=100,bootstrap=True)
        
    def _idfToLogIdf(self, idf):
        df = self._words / idf
        return math.log((self._words + 0.5) / (df + 0.5))
    
    def _getIdf(self, word):
        if word in self._wordToIndex:
            idx = self._wordToIndex[word]
            if self._useLogWeights:
                idf = self._log_idf_weights[word]
            return idx, idf
        if self._useLogWeights:
            return self._words, self._maxLogIdf
        return self._words, self._maxIdf
    
    def _docToVector(self, doc):
        """Convert a document (list of words) to a sparse matrix (vector)"""
        a_idx = np.zeros(len(doc))
        a_idf = np.zeros(len(doc))
        for i in range(len(doc)):
            w = doc[i]
            idx, idf = self._getIdf(w)
            a_idx[i] = idx
            a_idf[i] = idf
        return sparse.csc_matrix((a_idf,(a_idx, np.zeros(len(a_idx)))),shape=(self._words+1,1))

    def fit(self, X, y):
        train = [self._docToVector(doc) for doc in X]
        self._classifier = self._classifier.fit(train, y)
        return self

    def predict(self, X):
        test = [self._docToVector(doc) for doc in X]
        return self._classifier.predict(test)

    def predict_log_proba(self, X):
        test = [self._docToVector(doc) for doc in X]
        return self._classifier.predict_log_proba(test)        

    def score(self, X, y):
        test = [self._docToVector(doc) for doc in X]
        return self._classifier.score(test, y)

# %%
tfIdfTreeClassifier = TfIdfTreeClassifier(idf_weights)
tfIdfTreeClassifier = tfIdfTreeClassifier.fit(X[:1000], y[:1000])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-fc6212d1a492> in <module>()
#       1 tfIdfTreeClassifier = TfIdfTreeClassifier(idf_weights)
# ----> 2 tfIdfTreeClassifier = tfIdfTreeClassifier.fit(X[:1000], y[:1000])
#
# <ipython-input-31-c4a5c9517194> in fit(self, X, y)
#      45     def fit(self, X, y):
#      46         train = [self._docToVector(doc) for doc in X]
# ---> 47         self._classifier = self._classifier.fit(train, y)
#      48         return self
#      49
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if sample_weight is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: setting an array element with a sequence.

# %%
idf_weights['knive']
[(i,w) for i,w in enumerate([0,1,2,0,1])]
